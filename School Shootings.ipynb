# %%
# import necessary libraries
import os
import numpy as np

from flask import (
    Flask,
    render_template,
    jsonify,
    request,
    redirect)

from flask_sqlalchemy import SQLAlchemy
from sqlalchemy import func

from sqlalchemy.orm import aliased

# Postgres database user and password import
from db_key import user, password

#################################################
# Flask Setup
#################################################
app = Flask(__name__)

#################################################
# Database Setup
#################################################
try:
    db_uri = os.environ['DATABASE_URL']
except KeyError:
    db_uri = f'postgresql://{user}:{password}@localhost:5432/shooting1.sql'
app.config['SQLALCHEMY_DATABASE_URI'] = db_uri
db = SQLAlchemy(app)

#################################################
# Create classes to frame database table instance
#################################################


class shootings(db.Model):
    __tablename__ = 'shootings'

    lat = db.Column(db.Decimal, primary_key=True)
    long = db.Column(db.Decimal)
    state_id = db.Column(db.String(64))
    county = db.Column(db.String(64))
    city = db.Column(db.String(64))
	district_name = db.Column(db.String(64)) 
	school_name = db.Column(db.String(64))
	shooting_date = db.Column(db.datetime)
	day_of_week = db.Column(db.String(64)) 
	shooting_time = db.Column(db.datetime) 
	shooting_time1 = db.Column(db.String(64))
	school_type = db.Column(db.String(64)) 
	enrollment = db.Column(db.Integer)
    killed = db.Column(db.Integer)
	injured = db.Column(db.Integer)
	casualties = db.Column(db.Integer)
	shooting_type = db.Column(db.String(64))
	age_shooter1 = db.Column(db.Integer)
	gender_shooter1 = db.Column(db.String(64))
	race_ethnicity_shooter1 = db.Column(db.String(64))
	shooter_relationship1 = db.Column(db.String(64))
	shooter_deceased1 = db.Column(db.Integer)
	deceased_notes1 = db.Column(db.String(64))
	age_shooter2 = db.Column(db.Integer)
	gender_shooter2 = db.Column(db.String(64))
	race_ethnicity_shooter2 = db.Column(db.String(64))
	shooter_relationship2 = db.Column(db.String(64))
	shooter_deceased2 = db.Column(db.Integer)
	deceased_notes2 = db.Column(db.String(64))
	white = db.Column(db.Integer)
	black = db.Column(db.Integer)
	hispanic = db.Column(db.Integer)
	asian = db.Column(db.Integer)
	american_indian_alaska_native = db.Column(db.Integer)
	hawaiian_native_pacific_islander = db.Column(db.Integer)
	two_or_more = db.Column(db.Integer)
	resource_officer = db.Column(db.Integer)
	weapon = db.Column(db.String(64))
	weapon_source = db.Column(db.String(64))
	staffing = db.Column(db.Decimal) 
	lunch = db.Column(db.Integer)

    def __repr__(self):
        return '<shootings %r>' % (self.shootings)
# end shootings() class


class state_pop(db.Model):
    __tablename__ = 'state_pop'

    state = db.Column(db.String(64), primary_key=True)
	population = db.Column(db.Decimal)
	male = db.Column(db.Decimal)
	female = db.Column(db.Decimal) 
	white = db.Column(db.Decimal)
	black = db.Column(db.Decimal)
	native = db.Column(db.Decimal)
	asian = db.Column(db.Decimal)
	pacific = db.Column(db.Decimal)
	hispanic = db.Column(db.Decimal)
	per_capita_income = db.Column(db.Decimal)
	poverty_count = db.Column(db.Decimal)
	poverty_rate = db.Column(db.Decimal)

    def __repr__(self):
        return '<state_pop %r>' % (self.state_pop)
# end state_pop() class


class county_pop(db.Model):
    __tablename__ = 'county_pop'

    county = db.Column(db.Integer, primary_key=True)
	county_state = db.Column(db.String(64))
	population = db.Column(db.Decimal)
	male = db.Column(db.Decimal)
	female = db.Column(db.Decimal) 
	white = db.Column(db.Decimal)
	black = db.Column(db.Decimal)
	native = db.Column(db.Decimal)
	asian = db.Column(db.Decimal)
	pacific = db.Column(db.Decimal)
	hispanic = db.Column(db.Decimal)
	per_capita_income = db.Column(db.Decimal)
	poverty_count = db.Column(db.Decimal)
	poverty_rate = db.Column(db.Decimal)

    def __repr__(self):
        return '<county_pop %r>' % (self.county_pop)
# end county_pop() class
#################################################

# Query the database and send the jsonified results
@app.route("/send", methods=["GET", "POST"])
def send():
    if request.method == "POST":
        city = request.form["city"]
        state = request.form["state"]
        city = Cities(city=city, state=state)
        return redirect("/", code=302)
    return render_template("form.html")
# end send() route

# create route that renders index.html template


@app.route("/")
def home():
    return render_template("index.html")
# end home() route

@app.route("/trends")
def home():
    return render_template("trends.html")

#################################################
